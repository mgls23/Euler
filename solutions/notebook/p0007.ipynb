# %% [markdown]
# # [Problem 7: 10001st prime](https://projecteuler.net/problem=7)

# %% [markdown]
# > By listing the first six prime numbers, we see the 6th prime is 13. Find the 10001st prime number.

# %% [markdown]
# ## Approach 1: Sieve (used in latest solution)
# Estimate an upper bound using the prime number theorem, then sieve up to that limit.

# %%
import sys;

sys.path.insert(0, '..');
sys.path.insert(0, '../..')
from solutions.latest.p0007 import q7

print(q7())

# %% [markdown]
# ## Approach 2: Incremental primes (legacy approach)
# This uses the existing `PrimeGenerator` and checks candidates via trial division.

# %%
from solutions.euler.maths.prime import PrimeGenerator

print(PrimeGenerator().nth_prime_number(10001))
